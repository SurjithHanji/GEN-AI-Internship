# %%
# Q7 - Temperature Converter

# showing options
print("1. Celsius to Fahrenheit")
print("2. Fahrenheit to Celsius")
print("3. Celsius to Kelvin")
print("4. Kelvin to Celsius")
print("5. Fahrenheit to Kelvin")
print("6. Kelvin to Fahrenheit")
print("7. Exit")

# taking choice from user
ch = int(input("Enter your choice: "))

# if user chooses exit
if ch == 7:
    print("Program exited")

else:
    # taking temperature value only if not exiting
    t = float(input("Enter temperature: "))

    # checking choice and converting
    if ch == 1:
        result = (t * 9/5) + 32
        print("Converted Temperature:", result)

    elif ch == 2:
        result = (t - 32) * 5/9
        print("Converted Temperature:", result)

    elif ch == 3:
        result = t + 273.15
        print("Converted Temperature:", result)

    elif ch == 4:
        result = t - 273.15
        print("Converted Temperature:", result)

    elif ch == 5:
        result = (t - 32) * 5/9 + 273.15
        print("Converted Temperature:", result)

    elif ch == 6:
        result = (t - 273.15) * 9/5 + 32
        print("Converted Temperature:", result)

    else:
        print("Invalid Choice")
# Out:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 3. Celsius to Kelvin
# 4. Kelvin to Celsius
# 5. Fahrenheit to Kelvin
# 6. Kelvin to Fahrenheit
# Enter your choice:  1
# Enter temperature:  89
# Converted Temperature: 192.2
