# %%
# Q1: Personal Bio Card
# This program displays student information in a formatted box.

# Using variables for each field as required
student_name = "Surjith Hanji"
student_age = 21
course_name = "GEN AI"
college_name = "CMRIT"
email_address = "suha22cs@cmrit.ac.in"

# Display formatted bio card
print("+--------------------------------------+")
print("|          STUDENT BIO CARD            |")
print("+--------------------------------------+")
print("| Name    : ", student_name, "            |")
print("| Age     : ", student_age, "                       |")
print("| Course  : ", course_name, "                   |")
print("| College : ", college_name, "                    |")
print("| Email   : ", email_address, "     |")
print("=======================================")
# Out:
# +--------------------------------------+
# |          STUDENT BIO CARD            |
# +--------------------------------------+
# | Name    :  Surjith Hanji             |
# | Age     :  21                        |
# | Course  :  GEN AI                    |
# | College :  CMRIT                     |
# | Email   :  suha22cs@cmrit.ac.in      |
# ...
